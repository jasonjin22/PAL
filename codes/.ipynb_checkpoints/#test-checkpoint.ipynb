# %%
import imp
import GPy
import numpy as np
import read_data as rd
import plot_pareto as pp

# %%
imp.reload(rd)
# SNW data

# X_full, X, Y = rd.read_from_csv("snw")
# for i in range(len(Y)):
#     Y[i][0] = Y[i][0]*(-1)

# NOC data

X_full, X, Y = rd.read_from_csv("noc")
for i in range(len(Y)):
    Y[i][0] = Y[i][0]*(-1)
    
# LLVM data

# X_full, X, Y = rd.read_from_csv("llvm")
# Y[:, [0, 1]] = Y[:, [1, 0]]
# for i in range(len(Y)):
#     Y[i][0] = Y[i][0]*(-1)
print(X_full.shape, X.shape, Y.shape)
# Out:
# (259, 6) (259, 4) (259, 2)

# %%
kernel = GPy.kern.RBF(input_dim=4, variance=1., lengthscale=1.)

# %%
y1 = Y[:, 0][:,np.newaxis]
m = GPy.models.GPRegression(X,y1,kernel)

# %%
m.optimize(messages=True)
# Out:
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s04  0005   2.983567e+02   8.776394e+03
#     00s09  0013  -5.480957e+02   4.048008e+03
#     00s17  0024  -8.082898e+02   7.209217e+00
#     00s19  0027  -8.091392e+02   2.863273e+00
#     00s52  0088  -8.166912e+02   5.109362e-05
# Runtime:     00s52
# Optimization status: Errorb'ABNORMAL_TERMINATION_IN_LNSRCH'

# %%
for i in range(35):
    print(m.predict_noiseless(np.array([X[i]]))[0], m.predict_noiseless(np.array([X[i]]))[0] == m.predict(np.array([X[i]]))[0], m.predict_noiseless(np.array([X[i]]))[1], m.predict(np.array([X[i]]))[1], Y[i])
# Out:
# [[-7.83502308]] [[ True]] [[5.49406423e-08]] [[1.0945381e-07]] [-7.83510298  4.33936051]
# [[-7.83676971]] [[ True]] [[5.58364945e-08]] [[1.10349663e-07]] [-7.83683305  4.30919382]
# [[-9.96576559]] [[ True]] [[5.3631652e-08]] [[1.0814482e-07]] [-9.96578428  5.06615445]
# [[-7.95807969]] [[ True]] [[4.97825567e-08]] [[1.04295725e-07]] [-7.95823949  5.09653608]
# [[-7.95798528]] [[ True]] [[5.01675004e-08]] [[1.04680669e-07]] [-7.95823949  5.09653608]
# [[-7.95805318]] [[ True]] [[3.84292207e-08]] [[9.29423889e-08]] [-7.95823949  5.09653608]
# [[-7.95804934]] [[ True]] [[3.67863322e-08]] [[9.12995004e-08]] [-7.95823949  5.09653608]
# [[-7.07589031]] [[ True]] [[4.03980494e-08]] [[9.49112176e-08]] [-7.07588556  5.04157767]
# [[-7.07583904]] [[ True]] [[4.16763442e-08]] [[9.61895124e-08]] [-7.07588556  5.04157406]
# [[-7.07583599]] [[ True]] [[3.0506726e-08]] [[8.50198942e-08]] [-7.07588556  5.04157767]
# [[-7.07579841]] [[ True]] [[3.00306056e-08]] [[8.45437738e-08]] [-7.07588556  5.04157767]
# [[-8.90014027]] [[ True]] [[5.07035338e-08]] [[1.05216702e-07]] [-8.900257    5.10162063]
# [[-8.900065]] [[ True]] [[5.10989366e-08]] [[1.05612105e-07]] [-8.900257    5.10162063]
# [[-9.96578286]] [[ True]] [[5.35137588e-08]] [[1.08026927e-07]] [-9.96578428  5.06615445]
# [[-8.90012181]] [[ True]] [[3.92218453e-08]] [[9.37350135e-08]] [-8.900257    5.10162063]
# [[-8.90012217]] [[ True]] [[3.73271405e-08]] [[9.18403087e-08]] [-8.900257    5.10162063]
# [[-6.95154216]] [[ True]] [[3.74629963e-08]] [[9.19761645e-08]] [-6.95193742  4.79503586]
# [[-6.95069071]] [[ True]] [[3.56434384e-08]] [[9.01566066e-08]] [-6.9502351  4.7927667]
# [[-6.9513346]] [[ True]] [[2.77137815e-08]] [[8.22269497e-08]] [-6.95193742  4.79503586]
# [[-6.95158873]] [[ True]] [[2.76841092e-08]] [[8.21972774e-08]] [-6.95193742  4.79503586]
# [[-7.57894689]] [[ True]] [[4.25899316e-08]] [[9.71030998e-08]] [-7.57898399  5.09391423]
# [[-7.5788808]] [[ True]] [[4.00293629e-08]] [[9.45425311e-08]] [-7.57899908  5.09387097]
# [[-7.5789651]] [[ True]] [[3.2713956e-08]] [[8.72271242e-08]] [-7.57898399  5.09391255]
# [[-7.57896115]] [[ True]] [[3.19863602e-08]] [[8.64995284e-08]] [-7.57898399  5.09391428]
# [[-7.8819751]] [[ True]] [[5.00981514e-08]] [[1.0461132e-07]] [-7.88193375  4.67928881]
# [[-9.76671221]] [[ True]] [[4.81599045e-08]] [[1.02673073e-07]] [-9.76685186  5.11796517]
# [[-9.76661818]] [[ True]] [[4.43609451e-08]] [[9.88741134e-08]] [-9.76685186  5.11796517]
# [[-9.76669247]] [[ True]] [[3.64722155e-08]] [[9.09853837e-08]] [-9.76685186  5.11796517]
# [[-9.76668992]] [[ True]] [[3.57717909e-08]] [[9.02849591e-08]] [-9.76685186  5.11796517]
# [[-7.03586119]] [[ True]] [[3.29441718e-08]] [[8.745734e-08]] [-7.03566789  4.95355527]
# [[-7.03570101]] [[ True]] [[3.16130127e-08]] [[8.61261809e-08]] [-7.03577785  4.95276937]
# [[-7.03591357]] [[ True]] [[2.32678303e-08]] [[7.77809985e-08]] [-7.03566789  4.95355527]
# [[-7.03594136]] [[ True]] [[2.37637323e-08]] [[7.82769005e-08]] [-7.03566789  4.95355527]
# [[-8.05891832]] [[ True]] [[4.69480028e-08]] [[1.01461171e-07]] [-8.0591822   5.10760799]
# [[-8.05877698]] [[ True]] [[4.34308731e-08]] [[9.79440413e-08]] [-8.0591822   5.10760799]

# %%
imp.reload(pp)
# SNW data
# pp.plot_PF((-Y[:, 0]), (Y[:, 1]))

# LLVM data (looks different from the pic in the paper)
# pp.plot_PF((Y[:, 1]), (Y[:, 0]))


# noc data
pp.plot_points((Y[:, 0]), (Y[:, 1]))

imp.reload(pp)
Y_pareto = pp.find_pareto(Y)

pp.plot_points_with_pareto((Y[:, 0]), (Y[:, 1]), (Y_pareto[:, 0]),  (Y_pareto[:, 1]))

# %%
for i in Y_pareto:
    print(i)
# Out:
# [-6.1445155  4.9234265]
# [-6.29012946  5.02248465]
# [-6.65606727  5.08325538]
# [-7.11378383  5.10415768]
# [-7.73975361  5.11535473]
# [-8.78096948  5.12055439]
# [-9.67298569  5.12315989]
